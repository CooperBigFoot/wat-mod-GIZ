# %% [markdown]
# # Functions and Basic Type Hints
#
# In this notebook you will learn how to package useful logic into functions.
#
# By the end of the notebook, you should be able to:
#
# - define a function with `def`
# - pass values into a function through parameters
# - get a result back with `return`
# - read and write simple type hints
# - use functions that contain conditionals and loops
# - clean simple bad data and compute hydrology summaries with several functions together
#
# This notebook brings together many ideas from the earlier notebooks.

# %% [markdown]
# # Функции и базовые подсказки типов
#
# В этом ноутбуке вы узнаете, как упаковывать полезную логику в функции.
#
# К концу ноутбука вы должны уметь:
#
# - определять функцию с помощью `def`
# - передавать значения в функцию через параметры
# - получать результат обратно с помощью `return`
# - читать и писать простые подсказки типов
# - использовать функции, которые содержат условия и циклы
# - очищать простые ошибочные данные и вычислять гидрологические сводки с помощью нескольких функций вместе
#
# Этот ноутбук объединяет многие идеи из предыдущих ноутбуков.

# %% [markdown]
# ## How To Use This Notebook
#
# This notebook mixes explanation, code, and short exercises.
#
# Suggested rhythm:
#
# - read the markdown cell
# - run the example code cell
# - try the exercise yourself
# - compare your work with the exercise instructions
#
# Notebook state still matters: a later cell can use values created in an earlier cell.

# %% [markdown]
# ## Как пользоваться этим ноутбуком
#
# В этом ноутбуке есть объяснения, код и короткие упражнения.
#
# Рекомендуемый порядок работы:
#
# - прочитайте markdown-ячейку
# - запустите ячейку с примером кода
# - попробуйте выполнить упражнение самостоятельно
# - сравните свою работу с условиями упражнения
#
# Состояние ноутбука по-прежнему имеет значение: более поздняя ячейка может использовать значения, созданные в более ранней ячейке.

# %% [markdown]
# ## 1. Why Functions Help
#
# So far, you have written code step by step in notebook cells.
#
# That works well when a calculation is used once.
#
# But if we want to reuse the same logic several times, it is helpful to give that logic a name.
#
# A function lets us do exactly that.

# %% [markdown]
# ## 1. Зачем нужны функции
#
# До сих пор вы писали код шаг за шагом в ячейках ноутбука.
#
# Это хорошо работает, когда расчет используется один раз.
#
# Но если мы хотим повторно использовать одну и ту же логику несколько раз, полезно дать этой логике имя.
#
# Функция позволяет сделать именно это.

# %%
def rainfall_mm_to_cm(rainfall_mm):
    return rainfall_mm / 10.0

rainfall_cm = rainfall_mm_to_cm(12.0)
print(rainfall_cm)
# Out:
# 1.2

# %% [markdown]
# Here Python does two things:
#
# 1. it defines the function `rainfall_mm_to_cm`
# 2. it calls that function with the value `12.0`
#
# The `return` line sends the result back out of the function.

# %% [markdown]
# Здесь Python делает две вещи:
#
# 1. определяет функцию `rainfall_mm_to_cm`
# 2. вызывает эту функцию со значением `12.0`
#
# Строка `return` отправляет результат обратно из функции.

# %% [markdown]
# ### Exercise 1
#
# Write a function called `streamflow_lps_to_m3s`.
#
# It should:
#
# - take one input called `streamflow_lps`
# - convert liters per second to cubic meters per second
# - return the converted value
#
# Then call the function with `850.0` and store the result in `streamflow_m3s`.

# %% [markdown]
# ### Упражнение 1
#
# Напишите функцию `streamflow_lps_to_m3s`.
#
# Она должна:
#
# - принимать один входной параметр `streamflow_lps`
# - переводить литры в секунду в кубические метры в секунду
# - возвращать преобразованное значение
#
# Затем вызовите функцию со значением `850.0` и сохраните результат в `streamflow_m3s`.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## 2. Functions With Two Inputs
#
# A function can use more than one input.
#
# This is useful when a result depends on both data and a parameter.
#
# A simple runoff-coefficient calculation is a good example.

# %% [markdown]
# ## 2. Функции с двумя входными параметрами
#
# Функция может использовать больше одного входного параметра.
#
# Это полезно, когда результат зависит и от данных, и от параметра.
#
# Простой расчет коэффициента стока — хороший пример.

# %%
def compute_runoff_mm(rainfall_mm, runoff_coefficient):
    return rainfall_mm * runoff_coefficient

runoff_mm = compute_runoff_mm(18.0, 0.35)
print(runoff_mm)
# Out:
# 6.3

# %% [markdown]
# This function takes two inputs:
#
# - `rainfall_mm`
# - `runoff_coefficient`
#
# When we call the function, Python matches the input values to those parameter names and computes the result.

# %% [markdown]
# Эта функция принимает два входных параметра:
#
# - `rainfall_mm`
# - `runoff_coefficient`
#
# Когда мы вызываем функцию, Python сопоставляет входные значения с этими именами параметров и вычисляет результат.

# %% [markdown]
# ### Exercise 2
#
# Write a function called `storage_change_mm`.
#
# It should:
#
# - take `inflow_mm`
# - take `outflow_mm`
# - return `inflow_mm - outflow_mm`
#
# Then call it with `14.0` and `5.5` and store the result in `change_mm`.

# %% [markdown]
# ### Упражнение 2
#
# Напишите функцию `storage_change_mm`.
#
# Она должна:
#
# - принимать `inflow_mm`
# - принимать `outflow_mm`
# - возвращать `inflow_mm - outflow_mm`
#
# Затем вызовите ее со значениями `14.0` и `5.5` и сохраните результат в `change_mm`.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## 3. Functions With Conditional Logic
#
# A function can also make decisions inside its body.
#
# This connects directly to notebook 02.
#
# For example, we can write a function that checks whether a measurement is valid.

# %% [markdown]
# ## 3. Функции с условной логикой
#
# Функция также может принимать решения внутри своего тела.
#
# Это напрямую связано с ноутбуком 02.
#
# Например, мы можем написать функцию, которая проверяет, является ли измерение допустимым.

# %%
def is_valid_measurement(value_mm):
    if (value_mm < 0.0):
        return False
    else:
        return True

print(is_valid_measurement(4.5))
print(is_valid_measurement(-1.0))
# Out:
# True
# False

# %% [markdown]
# Here the rule is simple:
#
# - negative values are treated as invalid
# - zero and positive values are treated as valid
#
# This kind of rule will be useful in the final challenge.

# %% [markdown]
# Здесь правило простое:
#
# - отрицательные значения считаются недопустимыми
# - нулевые и положительные значения считаются допустимыми
#
# Такое правило будет полезно в финальном задании.

# %% [markdown]
# ### Exercise 3
#
# Write a function called `classify_precipitation_type`.
#
# It should:
#
# - return `"snow"` when `temperature_c` is less than or equal to `0.0`
# - otherwise return `"rain"`
#
# Then call it with `-2.5` and store the result in `phase_label`.

# %% [markdown]
# ### Упражнение 3
#
# Напишите функцию `classify_precipitation_type`.
#
# Она должна:
#
# - возвращать `"snow"`, когда `temperature_c` меньше или равно `0.0`
# - иначе возвращать `"rain"`
#
# Затем вызовите ее со значением `-2.5` и сохраните результат в `phase_label`.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## 4. Functions With Loops Inside
#
# A function can also contain a loop.
#
# This connects directly to notebook 03.
#
# That means a function can work through a whole list and return one summary result.

# %% [markdown]
# ## 4. Функции с циклами внутри
#
# Функция также может содержать цикл.
#
# Это напрямую связано с ноутбуком 03.
#
# Это значит, что функция может пройти по целому списку и вернуть один сводный результат.

# %%
def total_series_mm(series_mm):
    total_mm = 0.0

    for value_mm in series_mm:
        total_mm = total_mm + value_mm

    return total_mm

print(total_series_mm([12.0, 4.5, 0.0, 7.2]))
# Out:
# 23.7

# %% [markdown]
# The function starts a running total at `0.0`, loops through the list, and returns the final total.
#
# So the loop is now packaged inside a reusable function.

# %% [markdown]
# Функция начинает накопительную сумму с `0.0`, проходит циклом по списку и возвращает итоговую сумму.
#
# Теперь цикл упакован внутри функции, которую можно использовать повторно.

# %% [markdown]
# ### Exercise 4
#
# Write a function called `count_positive_days`.
#
# It should:
#
# - take a list called `series_mm`
# - count how many values are greater than `0.0`
# - return that count
#
# Then call it with `[0.0, 2.5, 1.0, 0.0, 4.2]` and store the result in `positive_day_count`.

# %% [markdown]
# ### Упражнение 4
#
# Напишите функцию `count_positive_days`.
#
# Она должна:
#
# - принимать список `series_mm`
# - считать, сколько значений больше `0.0`
# - возвращать это количество
#
# Затем вызовите ее со списком `[0.0, 2.5, 1.0, 0.0, 4.2]` и сохраните результат в `positive_day_count`.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## 5. Basic Type Hints
#
# Type hints are extra notes that explain what kinds of values a function expects and returns.
#
# They help humans read the code, and they can help tools check the code.
#
# Python does not need these hints in order to run the function.

# %% [markdown]
# ## 5. Базовые подсказки типов
#
# Подсказки типов — это дополнительные пометки, которые объясняют, какие виды значений функция ожидает и возвращает.
#
# Они помогают людям читать код, а также могут помогать инструментам проверять код.
#
# Python не нуждается в этих подсказках, чтобы запустить функцию.

# %%
def total_series_mm_typed(series_mm: list[float]) -> float:
    total_mm = 0.0

    for value_mm in series_mm:
        total_mm = total_mm + value_mm

    return total_mm

print(total_series_mm_typed([1.0, 2.5, 3.0]))
print(total_series_mm_typed.__annotations__)
# Out:
# 6.5
# {'series_mm': list[float], 'return': <class 'float'>}

# %% [markdown]
# Here the type hints say:
#
# - `series_mm: list[float]` means the function expects a list of decimal numbers
# - `-> float` means the function returns one decimal number
#
# You do not need to memorize all of this at once. For now, read type hints as helpful labels.

# %% [markdown]
# Здесь подсказки типов говорят:
#
# - `series_mm: list[float]` означает, что функция ожидает список десятичных чисел
# - `-> float` означает, что функция возвращает одно десятичное число
#
# Не нужно запоминать все сразу. Пока читайте подсказки типов как полезные метки.

# %% [markdown]
# ### Exercise 5
#
# Add simple type hints to this cleaning function.
#
# The function should:
#
# - take one value called `value_mm`
# - return `0.0` when the value is negative
# - otherwise return the original value
#
# Use `float` for the parameter and the return type.

# %% [markdown]
# ### Упражнение 5
#
# Добавьте простые подсказки типов к этой функции очистки.
#
# Функция должна:
#
# - принимать одно значение `value_mm`
# - возвращать `0.0`, когда значение отрицательное
# - иначе возвращать исходное значение
#
# Используйте `float` для параметра и возвращаемого типа.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## 6. Final Challenge: Clean Bad Data And Compute Summaries
#
# Now we can bring several ideas together.
#
# Imagine we receive a short precipitation series and a short runoff series.
#
# Some values are bad because they are negative. In this notebook, we will use a very simple cleaning rule:
#
# - if a value is negative, replace it with `0.0`
# - otherwise keep the value as it is
#
# Your challenge is to write several typed functions and use them together.

# %% [markdown]
# ## 6. Финальное задание: очистить ошибочные данные и вычислить сводки
#
# Теперь мы можем объединить несколько идей.
#
# Представьте, что мы получили короткий ряд осадков и короткий ряд стока.
#
# Некоторые значения ошибочные, потому что они отрицательные. В этом ноутбуке мы будем использовать очень простое правило очистки:
#
# - если значение отрицательное, заменить его на `0.0`
# - иначе оставить значение без изменений
#
# Ваша задача — написать несколько типизированных функций и использовать их вместе.

# %% [markdown]
# ### Final Exercise
#
# Use these input lists:
#
# - `precipitation_mm = [12.0, -3.0, 0.0, 8.5, 5.0]`
# - `runoff_mm = [3.0, 1.2, -0.5, 2.8, 1.0]`
#
# Write and use these functions:
#
# - `clean_series_mm(series_mm: list[float]) -> list[float]`
# - `total_series_mm(series_mm: list[float]) -> float`
# - `count_positive_days(series_mm: list[float]) -> int`
# - `runoff_ratio(total_runoff_mm: float, total_precip_mm: float) -> float`
# - `build_summary(total_precip_mm: float, total_runoff_mm: float, runoff_ratio_value: float) -> dict[str, float]`
#
# Then:
#
# 1. clean both lists
# 2. compute total cleaned precipitation
# 3. compute total cleaned runoff
# 4. count wet days in the cleaned precipitation series
# 5. compute the runoff ratio
# 6. build a summary dictionary with the totals and the ratio

# %% [markdown]
# ### Финальное упражнение
#
# Используйте эти входные списки:
#
# - `precipitation_mm = [12.0, -3.0, 0.0, 8.5, 5.0]`
# - `runoff_mm = [3.0, 1.2, -0.5, 2.8, 1.0]`
#
# Напишите и используйте эти функции:
#
# - `clean_series_mm(series_mm: list[float]) -> list[float]`
# - `total_series_mm(series_mm: list[float]) -> float`
# - `count_positive_days(series_mm: list[float]) -> int`
# - `runoff_ratio(total_runoff_mm: float, total_precip_mm: float) -> float`
# - `build_summary(total_precip_mm: float, total_runoff_mm: float, runoff_ratio_value: float) -> dict[str, float]`
#
# Затем:
#
# 1. очистите оба списка
# 2. вычислите суммарные очищенные осадки
# 3. вычислите суммарный очищенный сток
# 4. посчитайте влажные дни в очищенном ряду осадков
# 5. вычислите отношение стока к осадкам
# 6. постройте словарь сводки с суммами и отношением
#
# Пример решения ниже — один понятный способ сделать это.

# %%
# TODO: Write your solution here.

# %% [markdown]
# ## Wrap-Up
#
# You can now:
#
# - define functions with `def`
# - pass values into functions through parameters
# - return results from functions
# - read and write simple type hints
# - write functions that use conditionals and loops
# - use several functions together to clean bad data and compute simple hydrology summaries
#
# Next, you can build on this structure in later notebooks.

# %% [markdown]
# ## Итоги
#
# Теперь вы умеете:
#
# - определять функции с помощью `def`
# - передавать значения в функции через параметры
# - возвращать результаты из функций
# - читать и писать простые подсказки типов
# - писать функции, которые используют условия и циклы
# - использовать несколько функций вместе, чтобы очищать ошибочные данные и вычислять простые гидрологические сводки
#
# Далее вы сможете развивать эту структуру в следующих ноутбуках.
